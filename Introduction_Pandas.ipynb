# %% [markdown]
# # Introduction To Pandas
# -------------------------

# %% [markdown]
# Pandas is a Python library used for data manipulation and analysis.
# It provides powerful data structures, primarily DataFrame and Series, for handling structured data.

# %%
# Install pandas

# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# In pandas documentation, it is standard practice to import the library using the alias pd, and this convention is assumed throughout all examples.

# %%
#Import pandas library
import pandas as pd

# %%
# Check the version of the pandas
print(pd.__version__)
# Out:
# 2.1.4

# %% [markdown]
# I want to store passenger data of the df. Creating a columns name(Characters), age(int) and gender(male, female)

# %%
# To manually store data in a table, create a DataFrame
df = pd.DataFrame({
    'Name':  ["Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth"],
    'Age': [22, 35, 58],
    'Gender':["male", "male", "female"]
})

df
# Out:
#                        Name  Age  Gender
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df['Age']   # Display specific column
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [raw]
# A pandas Series has no column labels, as it represents a single column of data from a DataFrame. However, it does have row labels (known as the index), which identify each data point.

# %% [markdown]
# ## Basic Data Structure in Pandas

# %% [markdown]
# #### 1. Series:
# A Series is a one-dimensional labeled array that can hold any data type
# (integers, strings, floats, etc.).
#
# **Size Mutable:**
# - A Series is not easily resizable (size-mutable) like a DataFrame.
# - You cannot directly add or remove elements (rows) in a Series.
# - To change size, you must reassign or use methods that return a new Series.
# - You can modify existing values in a Series without changing its size.

# %%
# Creating Series
series = pd.Series([11,22,33,44,55])

# Reassigning to add an element
ser = pd.concat([series, pd.Series([66])], ignore_index= True)
print(ser)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    66
# dtype: int64

# %% [markdown]
# ### Homogeneous
#
# A Series is homogeneous by nature, meaning that all elements in a pandas Series are of
# the same data type.
#
# Although the Series itself can hold different types of data across different instances,
# within a single Series, all elements will be cast to the same type if possible.

# %%
ser = pd.Series([1, 'Alice', 3.5])  # Mixed data types

print(ser)
print(ser.dtypes)  # Checking the data type
# Out:
# 0        1
# 1    Alice
# 2      3.5
# dtype: object
# object

# %% [markdown]
# #### 2. DataFrame:
# A DataFrame is a two-dimensional, **size-mutable**, and potentially
# **heterogeneous** tabular data structure with labeled axes (rows and columns).
#
# _Note_: **heterogeneous** means that it can hold different data types in different columns.

# %%
# Creating Own DataFrames:
data = {"Name":["Jhon","Peter","Lisa"],      # String
        "Age":[24,27,30],                    # integer
        "Salary":[25000.0,30000.0,35000.0]}  #Float   
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age   Salary
# 0   Jhon   24  25000.0
# 1  Peter   27  30000.0
# 2   Lisa   30  35000.0

# %% [markdown]
# **Size-mutuable:** means that the number of rows and columns in a pandas DataFrame can be
# changed after its creation.
#
# We can:
# 1. Add new rows and columns.
# 2. Remove existing rows and columns

# %%
df = pd.DataFrame({'A':[1,2,3,4], 'B':[11,12,13,14]})

#Adding new column
df['C'] = [21,22,23,24]

#Removing column A
df.drop('A',axis = 1, inplace = True)                          # axis= 1 means column and axis = 0 means row

print(df)
# Out:
#     B   C
# 0  11  21
# 1  12  22
# 2  13  23
# 3  14  24

# %% [markdown]
# ### REMEMBER
#
# - Import the package, aka import pandas as pd
#
# - A table of data is stored as a pandas DataFrame
#
# - Each column in a DataFrame is a Series
#
# - You can do things by applying a method to a DataFrame or Series
#
# _______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Loading Data:
#
# **How do I read and write tabular data?**
#
# One of the primary uses of pandas is loading data into a DataFrame from various formats like CSV, Excel, JSON, etc.

# %% [markdown]
# - Pandas versatility: Supports multiple file formats or data sources natively.
#
# - Common formats: Include CSV, Excel, SQL, JSON, Parquet, etc.
#
# - Prefix convention: Each file format or source has a corresponding function with the prefix read_*.
#
# - Examples: read_excel(), read_json().

# %%
# Loading csv(comma separated values) file
import pandas as pd
data1 = pd.read_csv("C:/Users/hp/Desktop/Customers_Data.csv",encoding='latin-1')
print(data1)
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# 0          M       jon24@adventure-works.com     $90,000               2
# 1          M    eugene10@adventure-works.com     $60,000               3
# 2          M     ruben35@adventure-works.com     $60,000               3
# 3          F   christy12@adventure-works.com     $70,000               0
# 4          F  elizabeth5@adventure-works.com     $80,000               5
# ...      ...                             ...          ...            ...
# 18143      M      tommy2@adventure-works.com     $30,000               1
# 18144      F      nina21@adventure-works.com     $30,000               3
# 18145      M       ivan0@adventure-works.com     $30,000               3
# 18146      M    clayton0@adventure-works.com     $30,000               3
# 18147      M      jésus9@adventure-works.com     $30,000               0
#
#         EducationLevel    Occupation HomeOwner
# 0            Bachelors  Professional         Y
# 1            Bachelors  Professional         N
# 2            Bachelors  Professional         Y
# 3            Bachelors  Professional         N
# 4            Bachelors  Professional         Y
# ...                ...           ...       ...
# 18143  Graduate Degree      Clerical         Y
# 18144  Graduate Degree      Clerical         Y
# 18145  Graduate Degree      Clerical         N
# 18146        Bachelors      Clerical         Y
# 18147        Bachelors      Clerical         Y
#
# [18148 rows x 13 columns]

# %%
# Loading Excel file
data = pd.read_excel("C:/Users/hp/Desktop/Data Analyst/Excel FIle/ESD.xlsx")
print(data)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# 1             Manufacturing    Male      Asian   59 1997-11-29          99975
# 2       Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3             Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4             Manufacturing    Male      Asian   55 1995-11-20          95409
# ..                      ...     ...        ...  ...        ...            ...
# 995     Speciality Products    Male  Caucasian   33 2016-09-18          98427
# 996     Speciality Products  Female      Asian   44 2010-05-31          47387
# 997     Speciality Products    Male      Asian   31 2019-06-10         176710
# 998     Speciality Products  Female      Asian   33 2012-01-28          95960
# 999               Corporate  Female      Asian   63 2020-07-26         216195
#
#      Bonus %        Country       City  Exit Date
# 0       0.15  United States    Seattle 2021-10-16
# 1       0.00          China  Chongqing        NaT
# 2       0.20  United States    Chicago        NaT
# 3       0.07  United States    Chicago        NaT
# 4       0.00  United States    Phoenix        NaT
# ..       ...            ...        ...        ...
# 995     0.00  United States   Columbus        NaT
# 996     0.00          China    Chengdu 2018-01-08
# 997     0.15  United States      Miami        NaT
# 998     0.00          China    Chengdu        NaT
# 999     0.31  United States      Miami        NaT
#
# [1000 rows x 14 columns]

# %% [markdown]
# **to_string()**: function is used to print entire data

# %%
print(data.to_string())
# Out:
#        EEID             Full Name                       Job Title       Department           Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country            City  Exit Date
# 0    E02387           Emily Davis                      Sr. Manger               IT  Research & Development  Female      Black   55 2016-04-08         141604     0.15  United States         Seattle 2021-10-16
# 1    E04105         Theodore Dinh             Technical Architect               IT           Manufacturing    Male      Asian   59 1997-11-29          99975     0.00          China       Chongqing        NaT
# 2    E02572          Luna Sanders                        Director          Finance     Speciality Products  Female  Caucasian   50 2006-10-26         163099     0.20  United States         Chicago        NaT
# 3    E02832       Penelope Jordan        Computer Systems Manager               IT           Manufacturing  Female  Caucasian   26 2019-09-27          84913     0.07  United States         Chicago        NaT
# 4    E01639             Austin Vo                     Sr. Analyst          Finance           Manufacturing    Male      Asian   55 1995-11-20          95409     0.00  United States         Phoenix        NaT
# 5    E00644          Joshua Gupta          Account Representative            Sales               Corporate    Male      Asian   57 2017-01-24          50994     0.00          China       Chongqing        NaT
# 6    E01550           Ruby Barnes                         Manager               IT               Corporate  Female  Caucasian   27 2020-07-01         119746     0.10  United States         Phoenix        NaT
# 7    E04332           Luke Martin                         Analyst          Finance           Manufacturing    Male      Black   25 2020-05-16          41336     0.00  United States           Miami 2021-05-20
# 8    E04533         Easton Bailey                         Manager       Accounting           Manufacturing    Male  Caucasian   29 2019-01-25         113527     0.06  United States          Austin        NaT
# 9    E03838       Madeline Walker                     Sr. Analyst          Finance     Speciality Products  Female  Caucasian   34 2018-06-13          77203     0.00  United States         Chicago        NaT
# 10   E00591          Savannah Ali                      Sr. Manger  Human Resources           Manufacturing  Female      Asian   36 2009-02-11         157333     0.15  United States           Miami        NaT
# 11   E03344         Camila Rogers               Controls Engineer      Engineering     Speciality Products  Female  Caucasian   27 2021-10-21         109851     0.00  United States         Seattle        NaT
# 12   E00530             Eli Jones                         Manager  Human Resources           Manufacturing    Male  Caucasian   59 1999-03-14         105086     0.09  United States          Austin        NaT
# 13   E04239          Everleigh Ng                      Sr. Manger          Finance  Research & Development  Female      Asian   51 2021-06-10         146742     0.10          China        Shanghai        NaT
# 14   E03496           Robert Yang                     Sr. Analyst       Accounting     Speciality Products    Male      Asian   31 2017-11-04          97078     0.00  United States          Austin 2020-03-09
# 15   E00549           Isabella Xi                  Vice President        Marketing  Research & Development  Female      Asian   41 2013-03-13         249270     0.30  United States         Seattle        NaT
# 16   E00163          Bella Powell                        Director          Finance  Research & Development  Female      Black   65 2002-03-04         175837     0.20  United States         Phoenix        NaT
# 17   E00884          Camila Silva                      Sr. Manger        Marketing     Speciality Products  Female     Latino   64 2003-12-01         154828     0.13  United States         Seattle        NaT
# 18   E04116          David Barnes                        Director               IT               Corporate    Male  Caucasian   64 2013-11-03         186503     0.24  United States        Columbus        NaT
# 19   E04625             Adam Dang                        Director            Sales  Research & Development    Male      Asian   45 2002-07-09         166331     0.18          China       Chongqing        NaT
# 20   E03680        Elias Alvarado                      Sr. Manger               IT           Manufacturing    Male     Latino   56 2012-01-09         146140     0.10         Brazil          Manaus        NaT
# 21   E04732            Eva Rivera                        Director            Sales           Manufacturing  Female     Latino   36 2021-04-02         151703     0.21  United States           Miami        NaT
# 22   E03484          Logan Rivera                        Director               IT  Research & Development    Male     Latino   59 2002-05-24         172787     0.28         Brazil  Rio de Janerio        NaT
# 23   E00671        Leonardo Dixon                         Analyst            Sales     Speciality Products    Male  Caucasian   37 2019-09-05          49998     0.00  United States         Seattle        NaT
# 24   E02071             Mateo Her                  Vice President            Sales     Speciality Products    Male      Asian   44 2014-03-02         207172     0.31          China       Chongqing        NaT
# 25   E02206        Jose Henderson                        Director  Human Resources     Speciality Products    Male      Black   41 2015-04-17         152239     0.23  United States        Columbus        NaT
# 26   E04545         Abigail Mejia                Quality Engineer      Engineering               Corporate  Female     Latino   56 2005-02-05          98581     0.00         Brazil  Rio de Janerio        NaT
# 27   E00154            Wyatt Chin                  Vice President      Engineering     Speciality Products    Male      Asian   43 2004-06-07         246231     0.31  United States         Seattle        NaT
# 28   E03343             Carson Lu             Engineering Manager      Engineering     Speciality Products    Male      Asian   64 1996-12-04          99354     0.12          China         Beijing        NaT
# 29   E00304            Dylan Choi                  Vice President               IT               Corporate    Male      Asian   63 2012-05-11         231141     0.34          China         Beijing        NaT
# 30   E02594         Ezekiel Kumar                  IT Coordinator               IT  Research & Development    Male      Asian   28 2017-06-25          54775     0.00  United States        Columbus        NaT
# 31   E00402        Dominic Guzman                         Analyst          Finance           Manufacturing    Male     Latino   65 2004-05-16          55499     0.00         Brazil          Manaus        NaT
# 32   E01994          Angel Powell                      Analyst II            Sales  Research & Development    Male  Caucasian   61 2008-07-11          66521     0.00  United States         Seattle        NaT
# 33   E03549              Mateo Vu          Account Representative            Sales     Speciality Products    Male      Asian   30 2016-09-29          59100     0.00          China       Chongqing        NaT
# 34   E03247      Caroline Jenkins                         Analyst          Finance  Research & Development  Female  Caucasian   27 2018-05-06          49011     0.00  United States         Chicago        NaT
# 35   E02074            Nora Brown            Enterprise Architect               IT           Manufacturing  Female  Caucasian   32 2014-02-11          99575     0.00  United States          Austin        NaT
# 36   E04152         Adeline Huang               Controls Engineer      Engineering           Manufacturing  Female      Asian   34 2019-12-16          99989     0.00          China         Chengdu        NaT
# 37   E01628         Jackson Perry                  Vice President        Marketing  Research & Development    Male  Caucasian   27 2019-10-20         256420     0.30  United States         Phoenix        NaT
# 38   E04285         Riley Padilla             Technical Architect               IT           Manufacturing  Female     Latino   35 2013-05-15          78940     0.00  United States           Miami        NaT
# 39   E01417             Leah Pena            Enterprise Architect               IT               Corporate  Female     Latino   57 1994-01-03          82872     0.00         Brazil          Manaus        NaT
# 40   E01754              Owen Lam            Sr. Business Partner  Human Resources     Speciality Products    Male      Asian   30 2017-05-29          86317     0.00          China         Chengdu 2017-07-16
# 41   E03749        Kennedy Foster                         Manager        Marketing     Speciality Products  Female  Caucasian   53 2013-11-23         113135     0.05  United States          Austin        NaT
# 42   E03574            John Moore                  Vice President               IT     Speciality Products    Male  Caucasian   52 2005-11-08         199808     0.32  United States         Seattle        NaT
# 43   E04600            William Vu          Account Representative            Sales     Speciality Products    Male      Asian   37 2013-11-14          56037     0.00          China        Shanghai        NaT
# 44   E00586      Sadie Washington                      Sr. Manger        Marketing  Research & Development  Female  Caucasian   29 2019-05-24         122350     0.12  United States         Phoenix        NaT
# 45   E03538        Gabriel Holmes            Enterprise Architect               IT  Research & Development    Male  Caucasian   40 2010-11-04          92952     0.00  United States         Seattle        NaT
# 46   E02185           Wyatt Rojas        Computer Systems Manager               IT               Corporate    Male     Latino   32 2013-03-20          79921     0.05  United States          Austin        NaT
# 47   E03830           Eva Coleman                        Director               IT  Research & Development  Female      Black   37 2009-09-20         167199     0.20  United States         Seattle        NaT
# 48   E03720         Dominic Clark                Quality Engineer      Engineering  Research & Development    Male  Caucasian   52 2012-10-17          71476     0.00  United States         Phoenix        NaT
# 49   E03025        Lucy Alexander                        Director      Engineering           Manufacturing  Female  Caucasian   45 2014-10-29         189420     0.20  United States         Seattle        NaT
# 50   E04917  Everleigh Washington                    HRIS Analyst  Human Resources  Research & Development  Female  Caucasian   64 2001-10-20          64057     0.00  United States         Phoenix        NaT
# 51   E00415        Leilani Butler                      Analyst II        Marketing           Manufacturing  Female      Black   27 2021-09-21          68728     0.00  United States         Phoenix        NaT
# 52   E02862          Peyton Huang                      Sr. Manger               IT           Manufacturing  Female      Asian   25 2021-07-02         125633     0.11          China         Beijing        NaT
# 53   E04207        John Contreras                      Analyst II        Marketing           Manufacturing    Male     Latino   35 2011-05-15          66889     0.00  United States        Columbus        NaT
# 54   E02139              Rylee Yu                        Director       Accounting  Research & Development  Female      Asian   36 2015-09-29         178700     0.29  United States         Seattle        NaT
# 55   E01797           Piper Lewis                  Field Engineer      Engineering  Research & Development  Female  Caucasian   33 2018-12-22          83990     0.00  United States         Chicago        NaT
# 56   E01839      Stella Alexander             Automation Engineer      Engineering               Corporate  Female  Caucasian   52 2005-12-10         102043     0.00  United States         Chicago        NaT
# 57   E01633            Addison Do             Operations Engineer      Engineering           Manufacturing  Female      Asian   46 2001-05-30          90678     0.00  United States        Columbus        NaT
# 58   E01848          Zoey Jackson                Business Partner  Human Resources           Manufacturing  Female      Black   46 2008-08-21          59067     0.00  United States           Miami        NaT
# 59   E00716             John Chow                      Sr. Manger        Marketing  Research & Development    Male      Asian   45 2021-03-11         135062     0.15          China         Chengdu        NaT
# 60   E00699             Ava Ayala                      Sr. Manger               IT               Corporate  Female     Latino   55 2006-08-16         159044     0.10         Brazil          Manaus        NaT
# 61   E00502       Natalia Salazar                     Sr. Analyst       Accounting           Manufacturing  Female     Latino   44 2019-01-02          74691     0.00         Brazil          Manaus 2020-07-08
# 62   E04000       Skylar Carrillo             Engineering Manager      Engineering               Corporate  Female     Latino   44 2008-12-18          92753     0.13  United States          Austin 2021-06-24
# 63   E02112     Christian Sanders                  Vice President  Human Resources     Speciality Products    Male      Black   45 2013-08-07         236946     0.37  United States         Seattle        NaT
# 64   E03824      Penelope Coleman                         Analyst          Finance               Corporate  Female      Black   36 2021-08-27          48906     0.00  United States           Miami        NaT
# 65   E03906      Piper Richardson                     Sr. Analyst            Sales               Corporate  Female  Caucasian   38 2008-01-27          80024     0.00  United States        Columbus        NaT
# 66   E00436         Everly Walker                    HRIS Analyst  Human Resources     Speciality Products  Female  Caucasian   41 2009-10-23          54415     0.00  United States         Seattle 2014-01-22
# 67   E04798            Aurora Ali                         Manager        Marketing  Research & Development  Female      Asian   30 2016-04-24         120341     0.07  United States         Seattle        NaT
# 68   E01249     Penelope Guerrero                  Vice President               IT     Speciality Products  Female     Latino   43 2009-08-04         208415     0.35  United States         Seattle        NaT
# 69   E03349            Anna Mehta  Cloud Infrastructure Architect               IT     Speciality Products  Female      Asian   32 2020-01-05          78844     0.00  United States         Seattle        NaT
# 70   E02966        William Foster                  Field Engineer      Engineering           Manufacturing    Male  Caucasian   58 2002-05-23          76354     0.00  United States         Phoenix 2021-09-26
# 71   E01499            Jade Rojas                        Director          Finance     Speciality Products  Female     Latino   37 2019-01-28         165927     0.20  United States         Phoenix        NaT
# 72   E00105         Isla Espinoza                         Manager       Accounting     Speciality Products  Female     Latino   38 2021-11-16         109812     0.09         Brazil          Manaus        NaT
# 73   E00665             David Chu               Controls Engineer      Engineering               Corporate    Male      Asian   55 1998-09-03          86299     0.00  United States         Seattle        NaT
# 74   E00791        Thomas Padilla                  Vice President        Marketing  Research & Development    Male     Latino   57 2003-07-26         206624     0.40         Brazil       Sao Paulo        NaT
# 75   E01540         Miles Salazar                  IT Coordinator               IT           Manufacturing    Male     Latino   36 2010-12-23          53215     0.00         Brazil       Sao Paulo 2014-03-27
# 76   E04474             Mila Hong                   Test Engineer      Engineering  Research & Development  Female      Asian   30 2017-05-22          86858     0.00          China       Chongqing 2017-10-08
# 77   E03417         Benjamin Moua        Computer Systems Manager               IT           Manufacturing    Male      Asian   40 2007-07-02          93971     0.08          China       Chongqing        NaT
# 78   E00254        Samuel Morales                      Analyst II          Finance               Corporate    Male     Latino   34 2015-06-27          57008     0.00  United States         Phoenix        NaT
# 79   E02166             John Soto                      Sr. Manger          Finance           Manufacturing    Male     Latino   60 2015-09-23         141899     0.15  United States         Phoenix        NaT
# 80   E00935         Joseph Martin                      Analyst II        Marketing               Corporate    Male      Black   41 2016-09-13          64847     0.00  United States           Miami        NaT
# 81   E01525             Jose Ross             Engineering Manager      Engineering  Research & Development    Male  Caucasian   53 1992-04-08         116878     0.11  United States           Miami        NaT
# 82   E00386          Parker James                Quality Engineer      Engineering     Speciality Products    Male      Black   45 2005-02-05          70505     0.00  United States          Austin        NaT
# 83   E00416   Everleigh Fernandez                        Director      Engineering  Research & Development  Female     Latino   30 2016-05-22         189702     0.28         Brazil          Manaus 2020-12-21
# 84   E03383          Lincoln Hall                        Director       Accounting     Speciality Products    Male  Caucasian   26 2020-07-28         180664     0.27  United States         Chicago        NaT
# 85   E01516            Willow Mai                Business Partner  Human Resources           Manufacturing  Female      Asian   45 2003-12-17          48345     0.00          China         Chengdu        NaT
# 86   E01234            Jack Cheng                        Director  Human Resources           Manufacturing    Male      Asian   42 2014-01-16         152214     0.30          China         Beijing        NaT
# 87   E03440       Genesis Navarro  Cloud Infrastructure Architect               IT               Corporate  Female     Latino   41 2009-04-28          69803     0.00         Brazil          Manaus        NaT
# 88   E00431       Eliza Hernandez               Network Architect               IT               Corporate  Female     Latino   48 2019-07-04          76588     0.00         Brazil  Rio de Janerio        NaT
# 89   E01258        Gabriel Brooks                Network Engineer               IT           Manufacturing    Male  Caucasian   29 2018-12-10          84596     0.00  United States           Miami        NaT
# 90   E00440            Jack Huynh                         Manager        Marketing  Research & Development    Male      Asian   27 2018-09-25         114441     0.10          China       Chongqing 2019-12-22
# 91   E00595           Everly Chow                      Sr. Manger          Finance     Speciality Products  Female      Asian   33 2018-04-21         140402     0.15          China         Beijing        NaT
# 92   E00972        Amelia Salazar                      Analyst II          Finance               Corporate  Female     Latino   26 2019-04-23          59817     0.00         Brazil       Sao Paulo        NaT
# 93   E04562          Xavier Zheng          Account Representative            Sales           Manufacturing    Male      Asian   31 2017-07-22          55854     0.00  United States          Austin        NaT
# 94   E02802          Matthew Chau            Sr. Business Partner  Human Resources  Research & Development    Male      Asian   53 2002-11-16          95998     0.00  United States         Seattle        NaT
# 95   E01427             Mia Cheng                      Sr. Manger            Sales           Manufacturing  Female      Asian   34 2015-04-22         154941     0.13  United States         Phoenix        NaT
# 96   E04568              Rylee Yu                  Vice President          Finance     Speciality Products  Female      Asian   54 2011-07-10         247022     0.30          China         Beijing        NaT
# 97   E04931            Zoe Romero               Network Architect               IT           Manufacturing  Female     Latino   32 2021-10-05          88072     0.00         Brazil       Sao Paulo        NaT
# 98   E00443             Nolan Bui        Computer Systems Manager               IT  Research & Development    Male      Asian   28 2020-05-26          67925     0.08          China        Shanghai        NaT
# 99   E03890          Nevaeh Jones                  Vice President            Sales           Manufacturing  Female  Caucasian   31 2020-08-20         219693     0.30  United States          Austin        NaT
# 100  E01194        Samantha Adams                   Test Engineer      Engineering  Research & Development  Female  Caucasian   45 2013-04-22          61773     0.00  United States         Seattle        NaT
# 101  E02875         Madeline Shin        Computer Systems Manager               IT     Speciality Products  Female      Asian   48 2007-01-09          74546     0.09  United States         Seattle        NaT
# 102  E04959             Noah King            Development Engineer      Engineering     Speciality Products    Male      Black   56 2015-01-27          62575     0.00  United States           Miami        NaT
# 103  E03816          Leilani Chow                        Director  Human Resources               Corporate  Female      Asian   27 2021-02-23         199041     0.16          China         Beijing        NaT
# 104  E01261        Connor Simmons                      Analyst II       Accounting     Speciality Products    Male  Caucasian   55 2007-04-05          52310     0.00  United States           Miami 2018-10-12
# 105  E03612        Grayson Cooper                      Sr. Manger          Finance     Speciality Products    Male      Black   64 2013-06-29         159571     0.10  United States        Columbus        NaT
# 106  E01388              Ivy Soto                  Field Engineer      Engineering  Research & Development  Female     Latino   50 1997-10-23          91763     0.00  United States          Austin        NaT
# 107  E03875        Aurora Simmons            Development Engineer      Engineering               Corporate  Female  Caucasian   51 1995-12-22          96475     0.00  United States          Austin        NaT
# 108  E04413         Andrew Thomas               Controls Engineer      Engineering           Manufacturing    Male  Caucasian   36 2016-12-02         113781     0.00  United States        Columbus        NaT
# 109  E00691         Ezekiel Desai                        Director          Finance  Research & Development    Male      Asian   42 2003-01-15         166599     0.26  United States         Seattle        NaT
# 110  E03047       Gabriella Gupta      Sr. Account Representative            Sales               Corporate  Female      Asian   41 2005-02-15          95372     0.00          China        Shanghai        NaT
# 111  E04903            Skylar Liu                        Director               IT  Research & Development  Female      Asian   29 2020-08-09         161203     0.15          China         Chengdu        NaT
# 112  E04735          Nova Coleman           System Administrator                IT           Manufacturing  Female  Caucasian   44 2006-12-13          74738     0.00  United States           Miami        NaT
# 113  E02850           Evelyn Dinh                        Director            Sales  Research & Development  Female      Asian   41 2018-08-10         171173     0.21  United States        Columbus        NaT
# 114  E03583        Brooks Marquez                  Vice President            Sales               Corporate    Male     Latino   61 2019-09-24         201464     0.37  United States         Chicago        NaT
# 115  E02017         Connor Joseph                        Director  Human Resources               Corporate    Male  Caucasian   50 1998-07-22         174895     0.15  United States         Chicago        NaT
# 116  E01642               Mia Lam                      Sr. Manger               IT           Manufacturing  Female      Asian   49 2006-04-18         134486     0.14  United States          Austin        NaT
# 117  E04379    Scarlett Rodriguez                     Sr. Analyst          Finance           Manufacturing  Female     Latino   60 2007-02-24          71699     0.00         Brazil          Manaus        NaT
# 118  E04131           Cora Rivera                     Sr. Analyst        Marketing               Corporate  Female     Latino   42 2021-01-02          94430     0.00  United States         Seattle        NaT
# 119  E02872             Liam Jung                         Manager          Finance               Corporate    Male      Asian   39 2010-01-14         103504     0.07          China         Chengdu        NaT
# 120  E02331          Sophia Huynh            Enterprise Architect               IT           Manufacturing  Female      Asian   55 2005-08-09          92771     0.00  United States           Miami        NaT
# 121  E00417       Athena Carrillo                      Analyst II          Finance     Speciality Products  Female     Latino   39 2006-04-06          71531     0.00  United States        Columbus        NaT
# 122  E04267       Greyson Sanders  Cloud Infrastructure Architect               IT     Speciality Products    Male      Black   28 2019-03-06          90304     0.00  United States         Chicago        NaT
# 123  E03061          Vivian Lewis                         Manager        Marketing           Manufacturing  Female  Caucasian   65 2011-09-07         104903     0.10  United States        Columbus        NaT
# 124  E00013            Elena Vang                         Analyst          Finance               Corporate  Female      Asian   52 2019-02-19          55859     0.00          China         Beijing        NaT
# 125  E04265          Natalia Diaz             Operations Engineer      Engineering               Corporate  Female     Latino   62 2006-10-12          79785     0.00  United States          Austin        NaT
# 126  E04769            Mila Leung                     Sr. Analyst        Marketing               Corporate  Female      Asian   39 2007-11-05          99017     0.00          China         Beijing        NaT
# 127  E03042            Ava Nelson                 Systems Analyst               IT           Manufacturing  Female  Caucasian   63 1992-04-01          53809     0.00  United States         Phoenix        NaT
# 128  E00527             Mateo Chu                  Field Engineer      Engineering     Speciality Products    Male      Asian   27 2020-04-16          71864     0.00          China         Chengdu        NaT
# 129  E01095              Isla Lai                  Vice President          Finance               Corporate  Female      Asian   37 2011-12-06         225558     0.33          China        Shanghai        NaT
# 130  E03131          Ezekiel Reed                      Sr. Manger               IT           Manufacturing    Male  Caucasian   37 2014-02-25         128984     0.12  United States           Miami 2021-05-01
# 131  E01713          Nolan Guzman                  Field Engineer      Engineering     Speciality Products    Male     Latino   46 1999-06-20          96997     0.00         Brazil       Sao Paulo        NaT
# 132  E00128    Everleigh Espinoza                        Director  Human Resources           Manufacturing  Female     Latino   54 2018-01-22         176294     0.28  United States          Austin        NaT
# 133  E03849           Evelyn Jung                         Analyst            Sales  Research & Development  Female      Asian   30 2021-02-14          48340     0.00          China         Beijing        NaT
# 134  E02464          Sophie Silva                  Vice President      Engineering               Corporate  Female     Latino   28 2017-07-06         240488     0.40         Brazil  Rio de Janerio        NaT
# 135  E00306        Mateo Williams            Enterprise Architect               IT           Manufacturing    Male  Caucasian   40 2011-01-22          97339     0.00  United States          Austin        NaT
# 136  E03737        Kennedy Rahman                  Vice President  Human Resources           Manufacturing  Female      Asian   49 2003-02-28         211291     0.37          China       Chongqing        NaT
# 137  E02783           Levi Mendez                  Vice President            Sales  Research & Development    Male     Latino   39 2011-08-23         249506     0.30         Brazil  Rio de Janerio        NaT
# 138  E02939           Julian Fong                Quality Engineer      Engineering     Speciality Products    Male      Asian   61 2002-11-22          80950     0.00          China       Chongqing        NaT
# 139  E02706           Nevaeh Kang             Automation Engineer      Engineering  Research & Development  Female      Asian   46 2021-01-10          86538     0.00          China         Chengdu        NaT
# 140  E00170         Hannah Nelson                     Sr. Analyst        Marketing     Speciality Products  Female  Caucasian   35 2019-09-07          70992     0.00  United States          Austin        NaT
# 141  E01425        Anthony Rogers                  Vice President      Engineering               Corporate    Male  Caucasian   33 2015-06-18         205314     0.30  United States        Columbus        NaT
# 142  E00130          Paisley Kang                  Vice President  Human Resources               Corporate  Female      Asian   61 2017-03-10         196951     0.33          China         Beijing        NaT
# 143  E02094         Matthew Gupta                Network Engineer               IT     Speciality Products    Male      Asian   45 2005-09-18          67686     0.00          China         Beijing        NaT
# 144  E03567          Silas Chavez             Technical Architect               IT  Research & Development    Male     Latino   51 2008-04-15          86431     0.00  United States        Columbus        NaT
# 145  E04682           Colton Thao                         Manager  Human Resources           Manufacturing    Male      Asian   55 1995-11-16         125936     0.08          China       Chongqing        NaT
# 146  E00957         Genesis Perry                      Sr. Manger            Sales               Corporate  Female  Caucasian   46 2013-07-18         149712     0.14  United States        Columbus        NaT
# 147  E04458      Alexander Bryant                  Field Engineer      Engineering     Speciality Products    Male  Caucasian   30 2021-10-02          88758     0.00  United States         Seattle        NaT
# 148  E01499           Elias Zhang             Solutions Architect               IT  Research & Development    Male      Asian   54 2013-07-13          83639     0.00          China         Beijing        NaT
# 149  E00521           Lily Carter               Network Architect               IT  Research & Development  Female  Caucasian   54 1998-05-18          68268     0.00  United States         Phoenix        NaT
# 150  E03717           Joseph Ruiz                  Field Engineer      Engineering           Manufacturing    Male     Latino   45 2002-02-26          75819     0.00         Brazil       Sao Paulo        NaT
# 151  E01533          Avery Bailey                     Sr. Analyst            Sales     Speciality Products  Female  Caucasian   49 1996-05-15          86658     0.00  United States         Phoenix        NaT
# 152  E04449             Miles Hsu                      Analyst II          Finance  Research & Development    Male      Asian   55 2014-03-16          74552     0.00          China         Chengdu        NaT
# 153  E02855           Piper Cheng            Enterprise Architect               IT           Manufacturing  Female      Asian   62 2009-03-15          82839     0.00  United States           Miami        NaT
# 154  E00816         Skylar Watson               Network Architect               IT     Speciality Products  Female  Caucasian   28 2021-10-08          64475     0.00  United States         Phoenix        NaT
# 155  E02283            Jaxon Park               Network Architect               IT           Manufacturing    Male      Asian   33 2020-07-24          69453     0.00          China         Chengdu        NaT
# 156  E04888          Elijah Henry                         Manager               IT               Corporate    Male  Caucasian   32 2014-01-03         127148     0.10  United States           Miami        NaT
# 157  E03907         Camila Watson                  Vice President          Finance     Speciality Products  Female  Caucasian   32 2018-01-02         190253     0.33  United States          Austin        NaT
# 158  E02166          Lucas Thomas                         Manager       Accounting  Research & Development    Male  Caucasian   55 2000-04-28         115798     0.05  United States           Miami        NaT
# 159  E00431           Skylar Doan            Sr. Business Partner  Human Resources  Research & Development  Female      Asian   58 1994-08-21          93102     0.00  United States         Seattle 2013-12-13
# 160  E01501            Hudson Liu             Engineering Manager      Engineering     Speciality Products    Male      Asian   34 2017-11-16         110054     0.15  United States           Miami        NaT
# 161  E01141       Gianna Williams                Quality Engineer      Engineering  Research & Development  Female      Black   27 2021-01-28          95786     0.00  United States         Chicago        NaT
# 162  E02254       Jaxson Sandoval                     Sr. Analyst            Sales     Speciality Products    Male     Latino   61 2017-05-03          90855     0.00         Brazil       Sao Paulo        NaT
# 163  E04504      Jameson Alvarado            Enterprise Architect               IT           Manufacturing    Male     Latino   47 1999-03-14          92897     0.00         Brazil       Sao Paulo        NaT
# 164  E03394             Joseph Ly                  Vice President        Marketing     Speciality Products    Male      Asian   40 2009-02-28         242919     0.31          China       Chongqing        NaT
# 165  E02942     Daniel Richardson                        Director      Engineering     Speciality Products    Male  Caucasian   30 2018-05-20         184368     0.29  United States          Austin        NaT
# 166  E04130        Elias Figueroa                      Sr. Manger          Finance               Corporate    Male     Latino   45 2021-12-24         144754     0.15  United States         Phoenix        NaT
# 167  E02848           Emma Brooks      Sr. Account Representative            Sales  Research & Development  Female  Caucasian   30 2016-12-18          89458     0.00  United States          Austin        NaT
# 168  E00085             Isla Wong                  Vice President       Accounting               Corporate  Female      Asian   56 2014-03-16         190815     0.40  United States          Austin        NaT
# 169  E03956         Everly Walker                      Sr. Manger            Sales  Research & Development  Female  Caucasian   62 1999-08-02         137995     0.14  United States          Austin        NaT
# 170  E00672             Mila Pena            Sr. Business Partner  Human Resources           Manufacturing  Female     Latino   45 2007-12-21          93840     0.00         Brazil          Manaus        NaT
# 171  E04618            Mason Zhao             Technical Architect               IT  Research & Development    Male      Asian   46 2021-10-26          94790     0.00          China       Chongqing        NaT
# 172  E03506            Jaxson Mai                  Vice President  Human Resources  Research & Development    Male      Asian   48 2014-03-08         197367     0.39  United States          Austin        NaT
# 173  E00568             Ava Garza                        Director       Accounting           Manufacturing  Female     Latino   27 2018-06-25         174097     0.21  United States         Phoenix        NaT
# 174  E00535         Nathan Mendez                         Manager               IT     Speciality Products    Male     Latino   53 2006-10-31         120128     0.10  United States          Austin        NaT
# 175  E04630         Maria Griffin                         Manager        Marketing           Manufacturing  Female  Caucasian   59 2007-04-25         129708     0.05  United States           Miami        NaT
# 176  E00874        Alexander Choi                         Manager        Marketing  Research & Development    Male      Asian   55 1994-09-18         102270     0.10  United States         Chicago        NaT
# 177  E01546            Maria Hong                  Vice President          Finance     Speciality Products  Female      Asian   43 2005-07-31         249686     0.31          China       Chongqing        NaT
# 178  E00941            Sophie Ali                         Analyst          Finance           Manufacturing  Female      Asian   55 2002-03-28          50475     0.00  United States        Columbus        NaT
# 179  E03446           Julian Ross                         Manager        Marketing  Research & Development    Male  Caucasian   51 2020-07-02         100099     0.08  United States           Miami        NaT
# 180  E01361             Emma Hill                  IT Coordinator               IT           Manufacturing  Female  Caucasian   54 2016-12-27          41673     0.00  United States           Miami        NaT
# 181  E01631           Leilani Yee                     Sr. Analyst        Marketing     Speciality Products  Female      Asian   47 2017-07-12          70996     0.00          China         Chengdu        NaT
# 182  E03719            Jack Brown                         Analyst        Marketing               Corporate    Male  Caucasian   55 2004-12-07          40752     0.00  United States         Phoenix        NaT
# 183  E03269         Charlotte Chu                Network Engineer               IT           Manufacturing  Female      Asian   50 2001-01-23          97537     0.00          China         Chengdu        NaT
# 184  E01037          Jeremiah Chu            IT Systems Architect               IT  Research & Development    Male      Asian   31 2020-09-12          96567     0.00          China        Shanghai        NaT
# 185  E00671             Miles Cho                 Systems Analyst               IT     Speciality Products    Male      Asian   47 1999-03-10          49404     0.00          China         Beijing        NaT
# 186  E02216         Caleb Marquez            IT Systems Architect               IT  Research & Development    Male     Latino   29 2019-10-15          66819     0.00         Brazil  Rio de Janerio        NaT
# 187  E02803              Eli Soto                         Analyst        Marketing     Speciality Products    Male     Latino   38 2016-05-02          50784     0.00         Brazil  Rio de Janerio        NaT
# 188  E01584          Carter Mejia                      Sr. Manger  Human Resources  Research & Development    Male     Latino   29 2019-05-09         125828     0.15         Brazil       Sao Paulo        NaT
# 189  E02489           Ethan Clark            Sr. Business Partner  Human Resources           Manufacturing    Male  Caucasian   33 2017-08-04          92610     0.00  United States        Columbus        NaT
# 190  E03189         Asher Jackson                      Sr. Manger            Sales     Speciality Products    Male  Caucasian   50 2003-03-25         123405     0.13  United States        Columbus        NaT
# 191  E03560               Ayla Ng          Account Representative            Sales           Manufacturing  Female      Asian   46 2004-03-20          73004     0.00          China         Beijing        NaT
# 192  E00769             Jose Kang             Engineering Manager      Engineering               Corporate    Male      Asian   57 1999-04-25          95061     0.10          China        Shanghai        NaT
# 193  E02791         Aubrey Romero                        Director            Sales               Corporate  Female     Latino   49 1998-04-02         160832     0.30  United States         Phoenix        NaT
# 194  E02333         Jaxson Wright            Service Desk Analyst               IT           Manufacturing    Male      Black   54 2010-12-28          64417     0.00  United States        Columbus        NaT
# 195  E01002             Elias Ali                         Manager            Sales               Corporate    Male      Asian   28 2021-03-19         127543     0.06          China        Shanghai        NaT
# 196  E03520            Nolan Pena                         Analyst        Marketing           Manufacturing    Male     Latino   30 2018-06-21          56154     0.00         Brazil       Sao Paulo        NaT
# 197  E00752              Luna Liu                  Vice President            Sales           Manufacturing  Female      Asian   36 2014-02-22         218530     0.30          China        Shanghai        NaT
# 198  E00233        Brooklyn Reyes            Service Desk Analyst               IT           Manufacturing  Female     Latino   36 2019-12-19          91954     0.00  United States        Columbus        NaT
# 199  E02639         Hadley Parker                  Vice President        Marketing               Corporate  Female      Black   30 2016-09-21         221217     0.32  United States        Columbus 2017-09-25
# 200  E00697       Jonathan Chavez           System Administrator                IT           Manufacturing    Male     Latino   29 2017-05-11          87536     0.00  United States         Seattle        NaT
# 201  E02183           Sarah Ayala                         Analyst            Sales               Corporate  Female     Latino   47 2015-06-09          41429     0.00  United States         Seattle        NaT
# 202  E00715           Elijah Kang                  Vice President      Engineering           Manufacturing    Male      Asian   35 2011-10-10         245482     0.39  United States         Seattle        NaT
# 203  E04288            Ella White            Development Engineer      Engineering           Manufacturing  Female  Caucasian   25 2020-01-20          71359     0.00  United States         Phoenix        NaT
# 204  E02421         Jordan Truong                        Director      Engineering     Speciality Products    Male      Asian   45 2014-08-28         183161     0.22  United States           Miami        NaT
# 205  E00523         Daniel Jordan           Network Administrator               IT               Corporate    Male  Caucasian   58 1993-07-26          69260     0.00  United States         Phoenix        NaT
# 206  E03615          Daniel Dixon             Operations Engineer      Engineering     Speciality Products    Male  Caucasian   51 1999-10-09          95639     0.00  United States          Austin        NaT
# 207  E02761            Luca Duong                         Manager  Human Resources  Research & Development    Male      Asian   48 2004-06-30         120660     0.07          China         Chengdu        NaT
# 208  E02121            Levi Brown                     Sr. Analyst            Sales               Corporate    Male      Black   36 2021-12-26          75119     0.00  United States         Chicago        NaT
# 209  E01486             Mason Cho                  Vice President       Accounting  Research & Development    Male      Asian   59 2011-05-18         192213     0.40  United States         Chicago        NaT
# 210  E00725          Nova Herrera          Account Representative            Sales     Speciality Products  Female     Latino   45 2014-05-10          65047     0.00         Brazil       Sao Paulo        NaT
# 211  E03027         Elijah Watson                      Sr. Manger            Sales           Manufacturing    Male  Caucasian   29 2017-03-16         151413     0.15  United States         Seattle        NaT
# 212  E03689           Wesley Gray                     Sr. Analyst       Accounting     Speciality Products    Male  Caucasian   62 2003-04-22          76906     0.00  United States         Seattle        NaT
# 213  E01986         Wesley Sharma                         Manager               IT               Corporate    Male      Asian   51 1994-02-23         122802     0.05          China        Shanghai        NaT
# 214  E01286          Mateo Mendez            Development Engineer      Engineering  Research & Development    Male     Latino   47 1998-07-14          99091     0.00  United States          Austin        NaT
# 215  E01409           Jose Molina               Controls Engineer      Engineering           Manufacturing    Male     Latino   40 2008-02-28         113987     0.00         Brazil          Manaus        NaT
# 216  E00626          Luna Simmons                     Sr. Analyst          Finance               Corporate  Female  Caucasian   28 2020-09-04          95045     0.00  United States         Chicago        NaT
# 217  E04342       Samantha Barnes                  Vice President        Marketing     Speciality Products  Female  Caucasian   29 2017-01-05         190401     0.37  United States        Columbus        NaT
# 218  E03904          Hunter Ortiz                     Sr. Analyst          Finance               Corporate    Male     Latino   46 2013-01-20          86061     0.00         Brazil  Rio de Janerio        NaT
# 219  E01291        Thomas Aguilar      Sr. Account Representative            Sales     Speciality Products    Male     Latino   45 2021-02-10          79882     0.00  United States         Phoenix        NaT
# 220  E00917           Skylar Bell                  Vice President      Engineering           Manufacturing  Female  Caucasian   30 2018-03-06         255431     0.36  United States        Columbus        NaT
# 221  E01484              Anna Zhu            Service Desk Analyst               IT           Manufacturing  Female      Asian   48 2003-08-22          82017     0.00          China         Beijing        NaT
# 222  E03864           Ella Hunter                         Analyst          Finance           Manufacturing  Female  Caucasian   51 2017-01-18          53799     0.00  United States        Columbus        NaT
# 223  E00488          Emery Hunter                     Sr. Analyst            Sales               Corporate  Female  Caucasian   28 2021-07-03          82739     0.00  United States         Phoenix        NaT
# 224  E02227          Sofia Parker  Cloud Infrastructure Architect               IT           Manufacturing  Female  Caucasian   36 2014-05-30          99080     0.00  United States         Chicago        NaT
# 225  E04802             Lucy Fong      Sr. Account Representative            Sales               Corporate  Female      Asian   40 2011-01-20          96719     0.00          China         Chengdu        NaT
# 226  E01970         Vivian Barnes                        Director  Human Resources  Research & Development  Female  Caucasian   51 2021-03-28         180687     0.19  United States         Phoenix        NaT
# 227  E02813              Kai Chow             Engineering Manager      Engineering               Corporate    Male      Asian   45 2001-04-12          95743     0.15  United States          Austin 2010-01-15
# 228  E02031         Melody Cooper            Development Engineer      Engineering  Research & Development  Female  Caucasian   44 2009-09-04          89695     0.00  United States          Austin        NaT
# ...
# 924  E04163         David Herrera             Engineering Manager      Engineering     Speciality Products    Male     Latino   32 2021-10-09         102298     0.13         Brazil  Rio de Janerio        NaT
# 925  E01652       Avery Dominguez                      Sr. Manger            Sales               Corporate  Female     Latino   27 2019-09-13         133297     0.13         Brazil  Rio de Janerio        NaT
# 926  E00880          Grace Carter                      Sr. Manger  Human Resources     Speciality Products  Female      Black   25 2021-03-17         155080     0.10  United States          Austin        NaT
# 927  E04335          Parker Allen                     Sr. Analyst            Sales     Speciality Products    Male  Caucasian   31 2018-08-13          81828     0.00  United States           Miami        NaT
# 928  E01300             Sadie Lee                      Sr. Manger        Marketing               Corporate  Female      Asian   65 2000-10-24         149417     0.13          China         Chengdu        NaT
# 929  E03102         Cooper Valdez                         Manager            Sales               Corporate    Male     Latino   50 2012-04-25         113269     0.09         Brazil       Sao Paulo        NaT
# 930  E04089        Sebastian Fong                      Sr. Manger               IT           Manufacturing    Male      Asian   46 2017-12-16         136716     0.12  United States          Austin        NaT
# 931  E02059           Roman Munoz                      Sr. Manger            Sales     Speciality Products    Male     Latino   54 2011-10-20         122644     0.12  United States          Austin        NaT
# 932  E03894       Charlotte Chang                         Manager            Sales  Research & Development  Female      Asian   50 2000-05-07         106428     0.07  United States         Chicago        NaT
# 933  E03106          Xavier Davis                  Vice President          Finance               Corporate    Male  Caucasian   36 2009-01-17         238236     0.31  United States         Seattle        NaT
# 934  E01350        Natalie Carter                        Director          Finance               Corporate  Female  Caucasian   64 2012-12-21         153253     0.24  United States          Austin        NaT
# 935  E02900      Elena Richardson                         Manager       Accounting           Manufacturing  Female  Caucasian   34 2014-10-03         103707     0.09  United States        Columbus        NaT
# 936  E02202         Emilia Bailey                  Vice President       Accounting     Speciality Products  Female  Caucasian   41 2012-08-09         245360     0.37  United States          Austin        NaT
# 937  E02696               Ryan Lu            Development Engineer      Engineering     Speciality Products    Male      Asian   25 2021-07-08          67275     0.00  United States        Columbus        NaT
# 938  E01722           Asher Huynh                         Manager               IT           Manufacturing    Male      Asian   45 2015-01-22         101288     0.10  United States         Phoenix        NaT
# 939  E04562      Kinsley Martinez                        Director  Human Resources     Speciality Products  Female     Latino   52 1993-08-28         177443     0.25         Brazil       Sao Paulo        NaT
# 940  E00640        Paisley Bryant  Cloud Infrastructure Architect               IT           Manufacturing  Female      Black   37 2016-04-27          91400     0.00  United States         Chicago        NaT
# 941  E02554        Joshua Ramirez                  Vice President  Human Resources               Corporate    Male     Latino   44 2007-09-10         181247     0.33         Brazil       Sao Paulo        NaT
# 942  E03412         Joshua Martin                      Sr. Manger  Human Resources  Research & Development    Male      Black   42 2003-10-20         135558     0.14  United States         Phoenix        NaT
# 943  E00646         Charles Moore                         Analyst       Accounting     Speciality Products    Male  Caucasian   49 2011-12-17          56878     0.00  United States         Seattle        NaT
# 944  E04670              Angel Do            IT Systems Architect               IT     Speciality Products    Male      Asian   34 2019-09-20          94735     0.00          China         Beijing        NaT
# 945  E03580       Maverick Medina                      Analyst II            Sales           Manufacturing    Male     Latino   39 2007-05-27          51234     0.00  United States         Seattle        NaT
# 946  E00446             Isaac Han                  Vice President  Human Resources     Speciality Products    Male      Asian   31 2015-01-14         230025     0.34  United States         Phoenix        NaT
# 947  E02363           Eliza Liang                      Sr. Manger  Human Resources     Speciality Products  Female      Asian   36 2010-03-11         134006     0.13          China         Beijing        NaT
# 948  E03718              Zoe Zhou                         Manager          Finance               Corporate  Female      Asian   61 2009-10-06         103096     0.07          China         Beijing        NaT
# 949  E01749            Nathan Lee                         Analyst       Accounting           Manufacturing    Male      Asian   29 2016-08-20          58703     0.00  United States        Columbus        NaT
# 950  E02888          Elijah Ramos                      Sr. Manger               IT     Speciality Products    Male     Latino   33 2012-12-24         132544     0.10         Brazil  Rio de Janerio        NaT
# 951  E01338        Jaxson Coleman                         Manager          Finance           Manufacturing    Male  Caucasian   32 2020-04-15         126671     0.09  United States           Miami        NaT
# 952  E03000           Hailey Hong          Account Representative            Sales  Research & Development  Female      Asian   33 2021-01-22          56405     0.00  United States         Chicago        NaT
# 953  E01611         Gabriella Zhu        Computer Systems Manager               IT     Speciality Products  Female      Asian   36 2014-11-29          88730     0.08          China       Chongqing        NaT
# 954  E02684       Aaron Maldonado                      Analyst II          Finance           Manufacturing    Male     Latino   39 2008-09-17          62861     0.00  United States         Seattle        NaT
# 955  E02561       Samantha Vargas                        Director  Human Resources               Corporate  Female     Latino   53 2006-07-21         151246     0.21         Brazil       Sao Paulo        NaT
# 956  E03168               Nora Le                      Sr. Manger               IT           Manufacturing  Female      Asian   53 1997-04-12         154388     0.10  United States         Seattle        NaT
# 957  E00758         Alice Roberts                        Director  Human Resources           Manufacturing  Female  Caucasian   54 1994-09-26         162978     0.17  United States           Miami 2004-05-24
# 958  E03691         Colton Garcia             Solutions Architect               IT     Speciality Products    Male     Latino   55 1993-11-17          80170     0.00  United States           Miami        NaT
# 959  E01488            Stella Lai                     Sr. Analyst       Accounting           Manufacturing  Female      Asian   44 2021-04-28          98520     0.00  United States           Miami        NaT
# 960  E04415        Leonardo Luong                         Manager          Finance           Manufacturing    Male      Asian   52 1999-12-29         116527     0.07  United States         Phoenix        NaT
# 961  E03278         Nicholas Wong                        Director            Sales  Research & Development    Male      Asian   27 2019-11-07         174607     0.29  United States        Columbus        NaT
# 962  E00282     Jeremiah Castillo                      Analyst II       Accounting  Research & Development    Male     Latino   58 2006-04-12          64202     0.00  United States        Columbus        NaT
# 963  E03305          Cooper Jiang                      Analyst II       Accounting               Corporate    Male      Asian   49 2019-07-25          50883     0.00          China       Chongqing 2021-03-02
# 964  E00559        Penelope Silva               Network Architect               IT     Speciality Products  Female     Latino   36 2016-11-03          94618     0.00  United States        Columbus        NaT
# 965  E02558       Jose Richardson                        Director        Marketing  Research & Development    Male  Caucasian   26 2019-10-15         151556     0.20  United States           Miami        NaT
# 966  E00956          Eleanor Chau            Development Engineer      Engineering  Research & Development  Female      Asian   37 2020-03-08          80659     0.00  United States         Phoenix        NaT
# 967  E03858              John Cho                        Director  Human Resources     Speciality Products    Male      Asian   47 2019-11-03         195385     0.21          China         Chengdu        NaT
# 968  E02221        Julian Delgado                 Systems Analyst               IT     Speciality Products    Male     Latino   29 2016-05-19          52693     0.00         Brazil  Rio de Janerio        NaT
# 969  E00126        Isabella Scott           Network Administrator               IT  Research & Development  Female  Caucasian   58 2016-04-26          72045     0.00  United States         Phoenix        NaT
# 970  E02627          Parker Avila                      Analyst II        Marketing           Manufacturing    Male     Latino   47 2005-11-28          62749     0.00         Brazil          Manaus        NaT
# 971  E03778               Luke Vu                      Sr. Manger        Marketing     Speciality Products    Male      Asian   52 2018-06-04         154884     0.10          China        Shanghai        NaT
# 972  E00481        Jameson Nelson               Network Architect               IT  Research & Development    Male  Caucasian   61 2016-03-08          96566     0.00  United States        Columbus        NaT
# 973  E02833      Adrian Fernandez                 Systems Analyst               IT  Research & Development    Male     Latino   45 2001-08-23          54994     0.00  United States        Columbus        NaT
# 974  E03902        Madison Hunter           Network Administrator               IT               Corporate  Female  Caucasian   40 2012-02-05          61523     0.00  United States        Columbus        NaT
# 975  E02310       Jordan Phillips                  Vice President  Human Resources               Corporate    Male      Black   45 2010-12-12         190512     0.32  United States        Columbus        NaT
# 976  E02661             Maya Chan               Controls Engineer      Engineering     Speciality Products  Female      Asian   37 2013-02-13         124827     0.00          China         Beijing        NaT
# 977  E00836           Wesley King                         Manager       Accounting           Manufacturing    Male  Caucasian   57 2019-01-19         101577     0.05  United States         Chicago        NaT
# 978  E00682       Sofia Fernandez                         Manager       Accounting           Manufacturing  Female     Latino   44 2005-10-17         105223     0.10  United States         Phoenix        NaT
# 979  E00287     Maverick Figueroa            IT Systems Architect               IT               Corporate    Male     Latino   48 2008-07-06          94815     0.00  United States         Chicago        NaT
# 980  E00785          Hannah Hoang                         Manager       Accounting     Speciality Products  Female      Asian   25 2021-12-15         114893     0.06          China         Chengdu        NaT
# 981  E04598         Violet Garcia                     Sr. Analyst        Marketing     Speciality Products  Female     Latino   35 2017-01-10          80622     0.00  United States          Austin        NaT
# 982  E03247           Aaliyah Mai                  Vice President               IT     Speciality Products  Female      Asian   57 2016-11-11         246589     0.33  United States         Phoenix 2017-03-26
# 983  E02703           Austin Vang                         Manager        Marketing     Speciality Products    Male      Asian   49 2018-05-20         119397     0.09          China         Beijing 2019-03-14
# 984  E02191             Maria Sun                        Director            Sales               Corporate  Female      Asian   25 2021-12-19         150666     0.23          China         Chengdu        NaT
# 985  E00156         Madelyn Scott                      Sr. Manger               IT  Research & Development  Female  Caucasian   46 2002-01-09         148035     0.14  United States         Phoenix        NaT
# 986  E03349            Dylan Chin                        Director          Finance               Corporate    Male      Asian   60 2017-06-05         158898     0.18  United States           Miami        NaT
# 987  E04032           Emery Zhang                  Field Engineer      Engineering               Corporate  Female      Asian   45 2012-02-28          89659     0.00          China         Beijing        NaT
# 988  E00005      Riley Washington                        Director            Sales     Speciality Products  Female  Caucasian   39 2007-04-29         171487     0.23  United States         Phoenix        NaT
# 989  E04354          Raelynn Rios                  Vice President            Sales           Manufacturing  Female     Latino   43 2016-08-21         258498     0.35  United States        Columbus        NaT
# 990  E01578          Anthony Hong                      Sr. Manger               IT  Research & Development    Male      Asian   37 2010-11-29         146961     0.11  United States        Columbus        NaT
# 991  E03430           Leo Herrera            Sr. Business Partner  Human Resources  Research & Development    Male     Latino   48 1998-04-22          85369     0.00         Brazil          Manaus 2004-11-27
# 992  E03058         Robert Wright             Technical Architect               IT           Manufacturing    Male  Caucasian   30 2015-06-14          67489     0.00  United States         Chicago        NaT
# 993  E04762     Audrey Richardson                        Director               IT           Manufacturing  Female  Caucasian   46 2018-10-06         166259     0.17  United States         Chicago        NaT
# 994  E01148        Scarlett Kumar                 Systems Analyst               IT               Corporate  Female      Asian   55 2009-01-07          47032     0.00  United States        Columbus        NaT
# 995  E03094          Wesley Young                     Sr. Analyst        Marketing     Speciality Products    Male  Caucasian   33 2016-09-18          98427     0.00  United States        Columbus        NaT
# 996  E01909          Lillian Khan                         Analyst          Finance     Speciality Products  Female      Asian   44 2010-05-31          47387     0.00          China         Chengdu 2018-01-08
# 997  E04398           Oliver Yang                        Director        Marketing     Speciality Products    Male      Asian   31 2019-06-10         176710     0.15  United States           Miami        NaT
# 998  E02521           Lily Nguyen                     Sr. Analyst          Finance     Speciality Products  Female      Asian   33 2012-01-28          95960     0.00          China         Chengdu        NaT
# 999  E03545           Sofia Cheng                  Vice President       Accounting               Corporate  Female      Asian   63 2020-07-26         216195     0.31  United States           Miami        NaT

# %% [markdown]
# The number of rows returned is defined in pandas to see the maximum rows we can use
# **options.display.max_rows**

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 999   #Increase the maximum no. og rows to display entire data

# %% [markdown]
# ## Exploring Data in Pandas
#
# 1. Head()
# 2. Tail()
# 3. info()
# 4. describe()
# 5. shape
# 6. dtypes

# %% [markdown]
# **Head()**: It returns the headers and specified no. of rows strating from the top.
#
# _Note_: if the no. of rows are not specified, the head() method will return top 5 rows

# %%
data.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT
# 2     0.20  United States    Chicago        NaT
# 3     0.07  United States    Chicago        NaT
# 4     0.00  United States    Phoenix        NaT

# %% [markdown]
# **Tail()**: It returns the headers and specified no. of rows strating from the bottom.
#
# _Note_: If the no. of rows are not specified, the tail() method will return bottom 5 rowsws

# %%
data.tail()
# Out:
#        EEID     Full Name       Job Title  Department        Business Unit  \
# 995  E03094  Wesley Young     Sr. Analyst   Marketing  Speciality Products
# 996  E01909  Lillian Khan         Analyst     Finance  Speciality Products
# 997  E04398   Oliver Yang        Director   Marketing  Speciality Products
# 998  E02521   Lily Nguyen     Sr. Analyst     Finance  Speciality Products
# 999  E03545   Sofia Cheng  Vice President  Accounting            Corporate
#
#      Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country  \
# 995    Male  Caucasian   33 2016-09-18          98427     0.00  United States
# 996  Female      Asian   44 2010-05-31          47387     0.00          China
# 997    Male      Asian   31 2019-06-10         176710     0.15  United States
# 998  Female      Asian   33 2012-01-28          95960     0.00          China
# 999  Female      Asian   63 2020-07-26         216195     0.31  United States
#
#          City  Exit Date
# 995  Columbus        NaT
# 996   Chengdu 2018-01-08
# 997     Miami        NaT
# 998   Chengdu        NaT
# 999     Miami        NaT

# %% [markdown]
# **Info()**: It provides a summary that include the datatypes of each column and non null values present

# %%
data.info()         #Summary of the dataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %% [markdown]
# **describe()**: method provides a quick overview of the numerical data in a DataFrame.

# %%
data.describe()         # Statistics Summary
# Out:
#                Age                   Hire Date  Annual Salary      Bonus %  \
# count  1000.000000                        1000    1000.000000  1000.000000
# mean     44.382000  2012-04-07 02:54:14.400000  113217.365000     0.088660
# min      25.000000         1992-01-09 00:00:00   40063.000000     0.000000
# 25%      35.000000         2007-02-14 00:00:00   71430.250000     0.000000
# 50%      45.000000         2014-02-15 12:00:00   96557.000000     0.000000
# 75%      54.000000         2018-06-22 00:00:00  150782.250000     0.150000
# max      65.000000         2021-12-26 00:00:00  258498.000000     0.400000
# std      11.246981                         NaN   53545.985644     0.117856
#
#                            Exit Date
# count                             85
# mean   2016-11-02 18:04:14.117647104
# min              1994-12-18 00:00:00
# 25%              2014-12-25 00:00:00
# 50%              2019-05-23 00:00:00
# 75%              2021-04-09 00:00:00
# max              2022-08-17 00:00:00
# std                              NaN

# %% [markdown]
# **dtypes:** An attribute of a DataFrame or Series, used to check data types of columns.
#
# No brackets: Since it's an attribute, brackets are not required when accessing it.

# %%
# dtypes is attribute
data.dtypes            # Checking column dataTypes
# Out:
# EEID                     object
# Full Name                object
# Job Title                object
# Department               object
# Business Unit            object
# Gender                   object
# Ethnicity                object
# Age                       int64
# Hire Date        datetime64[ns]
# Annual Salary             int64
# Bonus %                 float64
# Country                  object
# City                     object
# Exit Date        datetime64[ns]
# dtype: object

# %% [markdown]
# **shape:** Returns a tuple representing the dimensions of the DataFrame (rows, columns).

# %%
data.shape            # Display the how many rows and column in a DataFrame
# Out:
# (1000, 14)

# %% [markdown]
# ### How to save data in a spreadsheet.
#
# to_* Methods: The to_* methods in pandas facilitate the export of data from a DataFrame or Series to various file formats.
#
# to_excel() Method: Specifically, the to_excel() method is used to save data as an Excel file.
#
# Customizations:
#
# sheet_name Parameter:
# This parameter allows users to define a custom name for the worksheet (e.g., sheet_name ='passengers'), overriding the default name of Sheet1.
#
# index Parameter:
# Setting (index=False) ensures that the row index labels are not included in the saved spreadsheet.

# %%
data.to_excel('ESD.xlsx', sheet_name = 'Details', index = False)   # Save the data into excel file
print('Successfully Saved')
# Out:
# Successfully Saved

# %% [markdown]
# ### REMEMBER
#
# Getting data in to pandas from many different file formats or data sources is supported by read_* functions.
#
# Exporting data out of pandas is provided by different to_*methods.
#
# The head/tail/info methods and the dtypes attribute are convenient for a first check.
#
# _______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## ATTRIBUTES in Pandas
#
# Attributes are characteristics or properties of a pandas object that return a value or information about that object without performing any actions. They don't need parentheses.
#
# **Example:** .shape, .columns, .dtype
#
# **_Series Attribute:_**
# 1. .index: Returns the index (labels) of the Series.
# 2. .values: Returns the underlying data as a NumPy array.
# 3. .dtype: Returns the data type of the elements in the Series.
# 4. .name: Returns or sets the name of the Series.

# %%
#1. .index
ser = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(ser.index)

#2. .values
ser = pd.Series([10, 20, 30])
print(ser.values)

#3. .dtypes
ser = pd.Series([10, 20, 30])
print(ser.dtype)

#4. .name
ser = pd.Series([10, 20, 30], name='my_series')
print(ser.name)
# Out:
# Index(['a', 'b', 'c'], dtype='object')
# [10 20 30]
# int64
# my_series

# %% [markdown]
# **_DataFrame Attributes_**
#
# 1. .columns: Returns the labels of columns in the DataFrame.
# 2. .shape: Returns a tuple representing the dimensions of the DataFrame (rows, columns).
# 3. .dtypes: Returns the data types of each column in the DataFrame.
# 4. .size: Returns the number of elements (rows × columns) in the DataFrame.
# 5. .ndim: Returns the number of dimensions of the DataFrame (should always be 2).
# 6. .empty: Returns True if the DataFrame is empty, otherwise False.

# %%
import pandas as pd

#1. .columns
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.columns)

#2. .shape
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.shape)

#3. .dtypes
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4.5, 5.5, 6.5]})
print(df.dtypes)

#4. .size
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.size)

#5. .ndim
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.ndim)

#6. .empty
df = pd.DataFrame({})
print(df.empty)
# Out:
# Index(['A', 'B'], dtype='object')
# (3, 2)
# A      int64
# B    float64
# dtype: object
# 6
# 2
# True

# %% [raw]
# Attribute |	Series | DataFrame | Description
# ------------------------------------------------------------------------------------------
# .index	     ✅	        ✅      Labels of rows.
# .values	     ✅	        ✅	     Data as NumPy array.
# .dtype	     ✅	        ✅	     Data type of the Series or DataFrame columns.
# .empty	     ✅	        ✅	     Check if object is empty.
# .ndim	     ✅ (1) 	✅ (2)	 Number of dimensions (1 for Series, 2 for DataFrame).
# .name	     ✅     	❌	     Name of the Series.
# .size	     ✅      	✅	     Total number of elements.
# .columns	 ❌     	✅	     Column labels of DataFrame.
# .shape	     ❌	        ✅	     Tuple of DataFrame dimensions (rows, columns).
# .dtypes      ❌     	✅	     Data types of DataFrame columns.
# .axes	     ❌	        ✅	     List of row and column labels (index and columns).
# _______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## How do I select specific columns from a DataFrame?
#
#
# Selecting a Column: To select a single column from a DataFrame, use square brackets  [] along with the column name.

# %%
# Selecting Single column
data['Full Name']
# Out:
# 0          Emily Davis
# 1        Theodore Dinh
# 2         Luna Sanders
# 3      Penelope Jordan
# 4            Austin Vo
#             ...
# 995       Wesley Young
# 996       Lillian Khan
# 997        Oliver Yang
# 998        Lily Nguyen
# 999        Sofia Cheng
# Name: Full Name, Length: 1000, dtype: object

# %% [markdown]
# __Returned Object:__
# Each column in a DataFrame is represented as a Series. Therefore, when a single column is selected, the output is a pandas Series.

# %% [markdown]
# #### Selecting Multiple Columns:
#
# To select multiple columns from a DataFrame, use a list of column names inside brackets [].
#
# Bracket Explanation:
# The inner brackets create a Python list of the column names, while the outer brackets select those columns from the DataFrame.

# %%
# Selecting Multiple Columns using []
data[['EEID','Full Name']]
# Out:
#        EEID        Full Name
# 0    E02387      Emily Davis
# 1    E04105    Theodore Dinh
# 2    E02572     Luna Sanders
# 3    E02832  Penelope Jordan
# 4    E01639        Austin Vo
# ..      ...              ...
# 995  E03094     Wesley Young
# 996  E01909     Lillian Khan
# 997  E04398      Oliver Yang
# 998  E02521      Lily Nguyen
# 999  E03545      Sofia Cheng
#
# [1000 rows x 2 columns]

# %%
data[['EEID','Full Name']].shape

# The selection returned a DataFrame with 1000 rows and 2 columns. Remember, a DataFrame is 2-dimensional with both a row and column dimension.
# Out:
# (1000, 2)

# %% [markdown]
# #### How do I filter specific rows from a DataFrame?

# %%
# Create a dataFrame

emp = {
    'Name': ['Alice','Bob','charlie','Dev'],
    'Age': [20, 18, 22, 23],
    'Marks': [28, 48, 20, 35]
}

df = pd.DataFrame(emp)
df
# Out:
#       Name  Age  Marks
# 0    Alice   20     28
# 1      Bob   18     48
# 2  charlie   22     20
# 3      Dev   23     35

# %%
# Filtering rows where age is greater than 30:

df_filtered = df[df['Marks']>30]
print(df_filtered)
# Out:
#   Name  Age  Marks
# 1  Bob   18     48
# 3  Dev   23     35

# %% [markdown]
# _Note:_ When using multiple conditions in filtering with pandas, you need to enclose each condition in parentheses **()** and use logical operators like **& (AND), | (OR)**.

# %%
#  Filtering using multiple conditions:

df_filtered1 = df[(df['Age']>=20) & (df['Name']=='Alice')]
print(df_filtered1)
# Out:
#     Name  Age  Marks
# 0  Alice   20     28

# %% [markdown]
# **loc[ ]:** is used for label-based indexing in a DataFrame, allowing access to rows and columns by their labels.
#
# Syntax: df.loc[row_labels, column_labels]

# %% [markdown]
# #### Correct way to select multiple columns

# %% [markdown]
# _Selecting Multiple Columns:_
#
# If you want to select multiple columns ('Name' and 'City'), you need to provide a list for the column labels.

# %%
res = df.loc[2,['Name','Marks']]
res
# Out:
# Name     charlie
# Marks         20
# Name: 2, dtype: object

# %% [markdown]
# #### Selecting Rows:
#
# Use a single label, a list of labels, or slices (e.g., df.loc[1] for the second row).

# %%
df.loc[2]
# Out:
# Name     charlie
# Age           22
# Marks         20
# Name: 2, dtype: object

# %% [markdown]
# #### Combining Rows and Columns:
#
# Access specific rows and columns together (e.g., df.loc[0:2, ['column1', 'column2']]).

# %%
df.loc[1:3,['Name','Age']]
# Out:
#       Name  Age
# 1      Bob   18
# 2  charlie   22
# 3      Dev   23

# %% [markdown]
# #### Selecting Columns:
#
# Specify column labels (e.g., df.loc[:, 'column_name'] for all rows of a specific column).

# %%
df.loc[:,['Name']]             # It print all rows of Name Column
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  charlie
# 3      Dev

# %% [markdown]
# #### Boolean Indexing:
#
# Filter rows based on conditions (e.g., df.loc[df['column_name'] > value]).

# %%
df.loc[df['Marks']>=30]
# Out:
#   Name  Age  Marks
# 1  Bob   18     48
# 3  Dev   23     35

# %% [markdown]
# #### When selecting specific rows and/or columns with loc or iloc, new values can be assigned to the selected data.
#
# For example, to assign the name anonymous to the first 3 elements of the fourth column:

# %%
df.iloc[1:3, 1] = 'Wrong Data'
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17764\3187554462.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Wrong Data' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[1:3, 1] = 'Wrong Data'
#       Name         Age  Marks
# 0    Alice          20     28
# 1      Bob  Wrong Data     48
# 2  charlie  Wrong Data     20
# 3      Dev          23     35

# %% [markdown]
# ### REMEMBER
#
# - When selecting subsets of data, square brackets [] are used.
#
# - Inside these brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# - Select specific rows and/or columns using loc when using the row and column names.
#
# - Select specific rows and/or columns using iloc when using the positions in the table.
#
# - You can assign new values to a selection based on loc/iloc.
#
# ________________________________________________________________________________________________________________________________________________________
